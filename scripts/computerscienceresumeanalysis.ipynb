# %% [markdown]
# ###### This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_Education = pd.read_json("../input/computerscience-resume-dataset/dataset_Education.json")

# %%
df_Education.head()

# %%
df_Education = df_Education.rename({0: "text"}, axis='columns')

# %%
df_Education["classe"] = ["Education"]* len(df_Education["text"])

# %%
df_Education.head()

# %%
df_Skills = pd.read_json("../input/computerscience-resume-dataset/dataset_Skills.json")

# %%
df_Skills = df_Skills.rename({0: "text"}, axis='columns')

# %%
df_Skills["classe"] = ["Skills"]* len(df_Skills["text"])

# %%
df_Skills.head()

# %%
df_Experience = pd.read_json("../input/computerscience-resume-dataset/dataset_Work Experience.json")

# %%
df_Experience = df_Experience.rename({0: "text"}, axis='columns')

# %%
df_Experience["classe"] = ["Experience"]* len(df_Experience["text"])

# %%
df_Experience.head()

# %%
df_Title = pd.read_json("../input/computerscience-resume-dataset/dataset_Title.json")

# %%
df_Title = df_Title.rename({0: "text"}, axis='columns')

# %%
df_Title["classe"] = ["Title"]* len(df_Experience["text"])

# %%
df_Title.head()

# %%
df_Certifications = pd.read_json("../input/computerscience-resume-dataset/dataset_Certifications.json")

# %%
df_Certifications = df_Certifications.rename({0: "text"}, axis='columns')

# %%
df_Certifications["classe"] = ["Certifications"]* len(df_Certifications["text"])

# %%
df_Certifications

# %%
df_Location = pd.read_json("../input/computerscience-resume-dataset/dataset_Location.json")

# %%
df_Location = df_Location.rename({0: "text"}, axis='columns')

# %%
df_Location["classe"] = ["Location"]* len(df_Location["text"])

# %%
df_Location

# %%
df_Additional_Information = pd.read_json("../input/computerscience-resume-dataset/dataset_Additional Information.json")

# %%
df_Additional_Information = df_Additional_Information.rename({0: "text"}, axis='columns')

# %%
df_Additional_Information["classe"] = ["Skills"]* len(df_Additional_Information["text"])

# %%
df_Additional_Information

# %%
df_Assessments = pd.read_json("../input/computerscience-resume-dataset/dataset_Assessments.json")

# %%
df_Assessments = df_Assessments.rename({0: "text"}, axis='columns')

# %%
df_Assessments["classe"] = ["Other"]* len(df_Assessments["text"])

# %%
df_Assessments

# %%
df_Awards = pd.read_json("../input/computerscience-resume-dataset/dataset_Awards.json")

# %%
df_Awards = df_Awards.rename({0: "text"}, axis='columns')

# %%
df_Awards["classe"] = ["Other"]* len(df_Awards["text"])

# %%
df_Awards

# %%
df_Groups = pd.read_json("../input/computerscience-resume-dataset/dataset_Groups.json")

# %%
df_Groups = df_Groups.rename({0: "text"}, axis='columns')

# %%
df_Groups["classe"] = ["Other"]* len(df_Groups["text"])

# %%
df_Groups

# %%
df_Military_Service = pd.read_json("../input/computerscience-resume-dataset/dataset_Military Service.json")

# %%
df_Military_Service = df_Military_Service.rename({0: "text"}, axis='columns')

# %%
df_Military_Service["classe"] = ["Other"]* len(df_Military_Service["text"])

# %%
df_Military_Service

# %%
df_Patents = pd.read_json("../input/computerscience-resume-dataset/dataset_Patents.json")

# %%
df_Patents = df_Patents.rename({0: "text"}, axis='columns')

# %%
df_Patents["classe"] = ["Other"]* len(df_Patents["text"])

# %%
df_Patents

# %%
df_Publications = pd.read_json("../input/computerscience-resume-dataset/dataset_Publications.json")

# %%
df_Publications = df_Publications.rename({0: "text"}, axis='columns')

# %%
df_Publications["classe"] = ["Other"]* len(df_Publications["text"])

# %%
df_Publications

# %%
df = pd.DataFrame(data={'text':[],'classe':[]})

# %%
df = (df
 .append(df_Education)
 .append(df_Skills) 
 .append(df_Experience)
 .append(df_Title)
 .append(df_Certifications) 
 .append(df_Location)
 .append(df_Additional_Information)
 .append(df_Assessments)
 .append(df_Awards) 
 .append(df_Groups)
 .append(df_Military_Service) 
 .append(df_Patents)
 .append(df_Publications)
 
)

# %%
df = pd.DataFrame(data={'text':df['text'],'classe':df['classe']})

# %%
df.describe()

# %%
df

# %%
df.to_csv("Resume_Dataset.csv")

# %%
df.read_csv("Resume_Dataset.csv")
